# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from scipy.spatial.distance import cdist

# %%
df_linear=pd.read_csv("/home/student/varshini/linear_dataset.csv")
df_lwr=pd.read_csv("/home/student/varshini/lwr_dataset.csv")
df_poly=pd.read_csv("/home/student/varshini/polynomial_dataset.csv")

# %%
df_linear
# Out:
#            X          Y
# 0    0.00000  12.292157
# 1    0.10101   8.503502
# 2    0.20202  10.542275
# 3    0.30303  14.631771
# 4    0.40404  13.814795
# ..       ...        ...
# 95   9.59596  37.907598
# 96   9.69697  36.122409
# 97   9.79798  41.751551
# 98   9.89899  37.077706
# 99  10.00000  38.205968
#
# [100 rows x 2 columns]

# %%
def linear_regression(df):
    X,y=df[['X']],df['Y']
    model=LinearRegression()
    model.fit(X,y)
    y_pred=model.predict(X)
    plt.scatter(X,y,label='Data')
    plt.plot(X,y_pred,color='red',label='Linear Regression')
    plt.legend()
    plt.title("Linear Regression")
    plt.show()
linear_regression(df_linear)

# %%
def gaussian_kernel(x,X,tau):
    return np.exp(-cdist([[x]],x,)/(2*tau**2))
